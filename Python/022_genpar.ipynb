# %% [markdown]
# 022 Generate Parentheses
#
# Given n pairs of parentheses, write a function to generate all combinations of well-formed parentheses.
#
# For example, given n = 3, a solution set is:
#
# [
#   "((()))",
#   "(()())",
#   "(())()",
#   "()(())",
#   "()()()"
# ]

# %%
from __future__ import print_function
import itertools



def generateParenthesis(n):
    """
    :type n: int
    :rtype: List[str]
    """
    # n pairs of parentheses
    ans = []
    
    # total num of parenthese:
    pars = '()'*n
    
    # permutations is bad O(n!)
    perms = list(set(list(itertools.permutations(pars, 2*n))))
    
    for i in range(0, len(perms)):
        print(perms[i])
        for j in range(0, 2*n):
            pass
    return ans

def helper(lst, s):
    if lst == 1:
        return s
    else:
        return [ y + x for y in permute(1, s) for x in permute(lst - 1, s)]

generateParenthesis(5)
# Out:
# ('(', ')', '(', ')', ')', ')', ')', '(', '(', '(')
# (')', ')', ')', '(', '(', ')', '(', ')', '(', '(')
# ('(', ')', ')', '(', ')', '(', ')', ')', '(', '(')
# (')', '(', ')', '(', '(', '(', ')', ')', ')', '(')
# (')', '(', '(', '(', ')', ')', ')', '(', ')', '(')
# (')', ')', ')', '(', '(', ')', '(', '(', '(', ')')
# ('(', ')', '(', ')', '(', '(', ')', ')', ')', '(')
# ('(', ')', ')', '(', ')', '(', ')', '(', ')', '(')
# (')', '(', ')', ')', '(', '(', '(', ')', ')', '(')
# ('(', '(', '(', ')', '(', ')', ')', '(', ')', ')')
# ('(', ')', '(', '(', ')', '(', ')', ')', ')', '(')
# (')', '(', ')', ')', ')', '(', ')', '(', '(', '(')
# ('(', ')', '(', '(', '(', '(', ')', ')', ')', ')')
# (')', '(', '(', ')', '(', ')', '(', ')', '(', ')')
# ('(', ')', ')', ')', '(', ')', '(', '(', '(', ')')
# ('(', '(', '(', ')', ')', ')', '(', ')', '(', ')')
# (')', ')', '(', '(', '(', '(', ')', '(', ')', ')')
# (')', '(', ')', '(', ')', '(', '(', '(', ')', ')')
# ('(', '(', ')', ')', '(', ')', '(', ')', ')', '(')
# ('(', ')', ')', '(', '(', ')', ')', '(', '(', ')')
# (')', ')', '(', '(', '(', ')', '(', ')', ')', '(')
# ('(', '(', '(', ')', '(', ')', ')', ')', ')', '(')
# (')', ')', '(', '(', '(', '(', '(', ')', ')', ')')
# (')', '(', '(', '(', '(', ')', ')', '(', ')', ')')
# ('(', ')', '(', ')', ')', '(', ')', '(', '(', ')')
# (')', '(', ')', '(', ')', '(', '(', ')', ')', '(')
# ('(', ')', '(', '(', ')', ')', ')', '(', ')', '(')
# ('(', ')', '(', '(', '(', ')', ')', ')', ')', '(')
# (')', ')', ')', '(', ')', '(', '(', '(', '(', ')')
# (')', '(', ')', '(', '(', ')', ')', ')', '(', '(')
# (')', '(', ')', '(', ')', ')', ')', '(', '(', '(')
# (')', ')', '(', '(', '(', ')', ')', '(', ')', '(')
# ('(', ')', '(', '(', ')', ')', ')', '(', '(', ')')
# ('(', ')', ')', ')', ')', '(', '(', '(', ')', '(')
# ('(', ')', ')', ')', '(', '(', ')', '(', ')', '(')
# ('(', ')', ')', ')', '(', '(', '(', '(', ')', ')')
# (')', '(', ')', '(', '(', '(', '(', ')', ')', ')')
# ('(', ')', '(', ')', '(', ')', '(', ')', ')', '(')
# ('(', ')', ')', '(', '(', '(', ')', ')', ')', '(')
# (')', '(', '(', ')', '(', ')', ')', ')', '(', '(')
# (')', ')', ')', '(', ')', '(', '(', ')', '(', '(')
# ('(', ')', ')', '(', ')', '(', '(', '(', ')', ')')
# (')', ')', '(', '(', '(', ')', '(', ')', '(', ')')
# (')', '(', '(', '(', ')', ')', '(', ')', '(', ')')
# (')', ')', '(', '(', '(', ')', '(', '(', ')', ')')
# ('(', '(', ')', ')', ')', ')', '(', '(', ')', '(')
# ('(', ')', ')', '(', ')', ')', ')', '(', '(', '(')
# (')', ')', ')', '(', ')', ')', '(', '(', '(', '(')
# (')', '(', '(', ')', '(', '(', ')', '(', ')', ')')
# ('(', ')', ')', ')', '(', '(', '(', ')', ')', '(')
# (')', '(', ')', '(', '(', '(', ')', '(', ')', ')')
# (')', '(', ')', ')', '(', '(', '(', '(', ')', ')')
# (')', ')', '(', '(', ')', ')', ')', '(', '(', '(')
# (')', ')', '(', ')', '(', ')', '(', '(', '(', ')')
# ('(', '(', ')', ')', '(', '(', ')', ')', ')', '(')
# (')', '(', ')', '(', '(', '(', ')', ')', '(', ')')
# (')', ')', ')', ')', '(', ')', '(', '(', '(', '(')
# ('(', ')', '(', '(', '(', ')', ')', '(', ')', ')')
# ('(', '(', ')', ')', ')', '(', '(', ')', '(', ')')
# (')', '(', '(', '(', ')', ')', ')', ')', '(', '(')
# ('(', '(', ')', '(', ')', ')', '(', ')', ')', '(')
# (')', '(', '(', '(', ')', '(', ')', ')', ')', '(')
# (')', '(', ')', ')', '(', ')', '(', ')', '(', '(')
# ('(', '(', ')', ')', ')', ')', ')', '(', '(', '(')
# ('(', '(', '(', '(', ')', ')', ')', ')', ')', '(')
# (')', '(', ')', '(', '(', ')', ')', '(', '(', ')')
# (')', '(', '(', '(', ')', '(', ')', '(', ')', ')')
# ('(', '(', ')', ')', ')', '(', '(', ')', ')', '(')
# ('(', ')', '(', ')', ')', ')', '(', '(', ')', '(')
# ('(', ')', ')', '(', '(', ')', '(', ')', ')', '(')
# (')', ')', '(', ')', '(', '(', ')', '(', ')', '(')
# (')', '(', '(', ')', ')', '(', '(', ')', ')', '(')
# (')', ')', '(', ')', '(', ')', '(', '(', ')', '(')
# (')', ')', ')', ')', '(', '(', ')', '(', '(', '(')
# (')', '(', '(', ')', '(', '(', ')', ')', '(', ')')
# ('(', ')', ')', ')', '(', ')', ')', '(', '(', '(')
# (')', '(', ')', '(', ')', '(', '(', ')', '(', ')')
# ('(', ')', '(', ')', '(', ')', '(', ')', '(', ')')
# (')', ')', ')', '(', '(', ')', ')', '(', '(', '(')
# ('(', ')', '(', ')', '(', '(', ')', '(', ')', ')')
# ('(', '(', ')', ')', '(', '(', ')', ')', '(', ')')
# ('(', ')', '(', '(', ')', '(', ')', ')', '(', ')')
# ('(', ')', '(', '(', ')', '(', '(', ')', ')', ')')
# (')', ')', '(', ')', ')', ')', '(', '(', '(', '(')
# ('(', ')', ')', ')', ')', '(', '(', '(', '(', ')')
# ('(', '(', '(', ')', ')', '(', ')', ')', ')', '(')
# ('(', ')', '(', ')', '(', ')', ')', '(', ')', '(')
# ('(', ')', '(', ')', '(', ')', '(', '(', ')', ')')
# (')', ')', ')', ')', '(', '(', '(', '(', '(', ')')
# ('(', '(', ')', ')', '(', ')', '(', '(', ')', ')')
# ('(', ')', ')', ')', '(', '(', ')', ')', '(', '(')
# (')', ')', '(', '(', '(', ')', ')', '(', '(', ')')
# ('(', '(', '(', '(', ')', ')', '(', ')', ')', ')')
# (')', '(', ')', ')', '(', ')', ')', '(', '(', '(')
# ('(', ')', ')', '(', ')', ')', '(', '(', ')', '(')
# ('(', '(', ')', '(', '(', ')', ')', ')', ')', '(')
# ('(', '(', '(', ')', ')', ')', ')', '(', ')', '(')
# ('(', '(', ')', '(', '(', ')', '(', ')', ')', ')')
# ('(', ')', '(', ')', ')', '(', ')', '(', ')', '(')
# ('(', '(', '(', ')', ')', '(', ')', ')', '(', ')')
# (')', '(', '(', '(', ')', '(', ')', ')', '(', ')')
# ('(', '(', '(', ')', ')', '(', ')', '(', ')', ')')
# ('(', ')', '(', ')', ')', ')', '(', ')', '(', '(')
# (')', ')', ')', '(', '(', '(', ')', '(', '(', ')')
# ('(', '(', ')', ')', '(', ')', '(', ')', '(', ')')
# ('(', ')', '(', '(', ')', ')', '(', ')', '(', ')')
# (')', '(', '(', ')', ')', ')', '(', '(', '(', ')')
# ('(', '(', '(', '(', ')', ')', ')', ')', '(', ')')
# ('(', '(', '(', '(', ')', ')', ')', '(', ')', ')')
# ('(', '(', ')', '(', '(', ')', ')', '(', ')', ')')
# ('(', ')', '(', ')', ')', '(', '(', ')', ')', '(')
# (')', ')', ')', '(', '(', '(', '(', ')', '(', ')')
# (')', '(', ')', '(', ')', ')', '(', '(', ')', '(')
# (')', '(', '(', ')', '(', ')', '(', ')', ')', '(')
# ('(', '(', ')', ')', ')', '(', ')', '(', '(', ')')
# ('(', '(', '(', ')', '(', ')', ')', ')', '(', ')')
# ('(', '(', ')', ')', ')', '(', '(', '(', ')', ')')
# ('(', ')', ')', ')', '(', '(', '(', ')', '(', ')')
# (')', ')', '(', '(', ')', '(', '(', ')', '(', ')')
# (')', ')', '(', ')', ')', '(', '(', '(', ')', '(')
# ('(', ')', ')', '(', '(', '(', ')', ')', '(', ')')
# ('(', '(', ')', '(', ')', '(', ')', ')', ')', '(')
# ('(', ')', ')', ')', '(', ')', '(', '(', ')', '(')
# (')', '(', '(', '(', '(', ')', ')', ')', '(', ')')
# ('(', '(', '(', '(', ')', '(', ')', ')', ')', ')')
# (')', ')', ')', '(', ')', '(', '(', '(', ')', '(')
# (')', '(', '(', '(', '(', ')', '(', ')', ')', ')')
# (')', '(', ')', ')', '(', ')', '(', '(', '(', ')')
# (')', '(', '(', ')', ')', '(', '(', '(', ')', ')')
# ('(', ')', ')', '(', ')', ')', '(', '(', '(', ')')
# (')', '(', ')', ')', '(', ')', '(', '(', ')', '(')
# (')', '(', '(', '(', ')', ')', ')', '(', '(', ')')
# (')', ')', '(', '(', '(', '(', ')', ')', '(', ')')
# (')', '(', ')', '(', ')', '(', ')', ')', '(', '(')
# ('(', '(', '(', ')', ')', ')', '(', '(', ')', ')')
# ('(', ')', '(', ')', ')', '(', ')', ')', '(', '(')
# (')', '(', ')', '(', ')', '(', ')', '(', ')', '(')
# (')', ')', '(', ')', '(', '(', ')', '(', '(', ')')
# (')', '(', '(', ')', ')', '(', ')', '(', '(', ')')
# (')', '(', '(', '(', ')', ')', '(', ')', ')', '(')
# (')', '(', '(', ')', ')', '(', ')', '(', ')', '(')
# ('(', '(', '(', ')', ')', ')', ')', ')', '(', '(')
# (')', ')', '(', ')', '(', '(', '(', ')', ')', '(')
# (')', ')', ')', '(', ')', '(', ')', '(', '(', '(')
# ('(', ')', '(', '(', ')', ')', ')', ')', '(', '(')
# (')', '(', ')', ')', ')', '(', '(', '(', '(', ')')
# (')', '(', '(', ')', ')', ')', ')', '(', '(', '(')
# (')', '(', ')', ')', '(', '(', '(', ')', '(', ')')
# ('(', ')', ')', ')', ')', ')', '(', '(', '(', '(')
# ('(', '(', ')', ')', '(', '(', ')', '(', ')', ')')
# (')', '(', '(', '(', '(', ')', ')', ')', ')', '(')
# ('(', '(', '(', ')', ')', '(', '(', ')', ')', ')')
# (')', ')', ')', '(', '(', '(', ')', ')', '(', '(')
# ('(', ')', ')', '(', '(', ')', '(', ')', '(', ')')
# (')', '(', ')', '(', '(', ')', '(', ')', ')', '(')
# (')', ')', ')', '(', '(', ')', '(', '(', ')', '(')
# (')', ')', '(', '(', ')', '(', ')', '(', ')', '(')
# ('(', '(', ')', '(', ')', '(', '(', ')', ')', ')')
# (')', '(', '(', '(', '(', '(', ')', ')', ')', ')')
# ('(', ')', '(', ')', '(', '(', '(', ')', ')', ')')
# ('(', '(', ')', '(', ')', ')', ')', ')', '(', '(')
# ('(', ')', '(', '(', ')', ')', '(', ')', ')', '(')
# ('(', ')', ')', '(', ')', '(', ')', '(', '(', ')')
# (')', '(', ')', ')', ')', '(', '(', ')', '(', '(')
# ('(', ')', ')', ')', ')', '(', '(', ')', '(', '(')
# (')', '(', '(', ')', '(', ')', ')', '(', '(', ')')
# ('(', ')', ')', ')', '(', '(', ')', '(', '(', ')')
# ('(', ')', '(', ')', '(', '(', ')', ')', '(', ')')
# ('(', '(', ')', ')', '(', ')', ')', '(', ')', '(')
# ('(', ')', ')', '(', '(', ')', ')', ')', '(', '(')
# ('(', '(', ')', ')', ')', ')', '(', ')', '(', '(')
# (')', ')', '(', ')', '(', '(', '(', '(', ')', ')')
# ('(', '(', ')', '(', ')', '(', ')', ')', '(', ')')
# ('(', '(', ')', '(', ')', '(', ')', '(', ')', ')')
# (')', ')', '(', '(', '(', ')', ')', ')', '(', '(')
# (')', '(', ')', ')', '(', '(', ')', '(', ')', '(')
# (')', '(', ')', '(', '(', ')', ')', '(', ')', '(')
# ('(', '(', '(', ')', '(', ')', '(', ')', ')', ')')
# ('(', '(', '(', '(', '(', ')', ')', ')', ')', ')')
# ('(', ')', '(', ')', ')', '(', '(', '(', ')', ')')
# ('(', ')', ')', '(', '(', '(', '(', ')', ')', ')')
# (')', ')', ')', ')', '(', '(', '(', ')', '(', '(')
# ('(', ')', ')', '(', '(', '(', ')', '(', ')', ')')
# ('(', ')', ')', ')', '(', ')', '(', ')', '(', '(')
# ('(', '(', '(', ')', ')', ')', ')', '(', '(', ')')
# (')', ')', '(', '(', '(', '(', ')', ')', ')', '(')
# ('(', '(', ')', '(', '(', '(', ')', ')', ')', ')')
# ('(', '(', ')', ')', '(', ')', ')', ')', '(', '(')
# ('(', ')', '(', '(', ')', ')', '(', '(', ')', ')')
# ('(', '(', ')', '(', ')', ')', ')', '(', '(', ')')
# (')', '(', '(', '(', ')', '(', '(', ')', ')', ')')
# (')', '(', ')', ')', ')', '(', '(', '(', ')', '(')
# ('(', '(', ')', ')', '(', ')', ')', '(', '(', ')')
# (')', ')', '(', '(', ')', '(', ')', ')', '(', '(')
# (')', ')', '(', '(', ')', '(', '(', '(', ')', ')')
# (')', ')', ')', '(', '(', '(', '(', '(', ')', ')')
# ('(', '(', ')', ')', '(', '(', '(', ')', ')', ')')
# (')', ')', ')', '(', '(', '(', ')', '(', ')', '(')
# (')', '(', '(', ')', ')', ')', '(', ')', '(', '(')
# (')', ')', '(', ')', '(', '(', '(', ')', '(', ')')
# (')', '(', ')', '(', ')', ')', '(', ')', '(', '(')
# ('(', ')', ')', '(', '(', ')', ')', '(', ')', '(')
# ('(', '(', ')', ')', ')', '(', ')', '(', ')', '(')
# ('(', ')', '(', '(', ')', '(', ')', '(', ')', ')')
# ('(', '(', ')', '(', ')', ')', ')', '(', ')', '(')
# (')', '(', ')', '(', '(', ')', '(', ')', '(', ')')
# ('(', '(', ')', '(', ')', ')', '(', '(', ')', ')')
# (')', '(', '(', ')', '(', '(', '(', ')', ')', ')')
# (')', ')', '(', '(', ')', '(', '(', ')', ')', '(')
# ('(', ')', '(', ')', '(', ')', ')', ')', '(', '(')
# ('(', '(', '(', ')', '(', '(', ')', ')', ')', ')')
# (')', '(', '(', ')', '(', '(', ')', ')', ')', '(')
# ('(', '(', ')', ')', ')', ')', '(', '(', '(', ')')
# (')', ')', '(', '(', ')', ')', '(', '(', '(', ')')
# (')', '(', ')', '(', ')', ')', '(', '(', '(', ')')
# (')', ')', '(', ')', '(', ')', ')', '(', '(', '(')
# (')', '(', ')', ')', '(', '(', ')', ')', '(', '(')
# (')', ')', '(', ')', '(', '(', ')', ')', '(', '(')
# ('(', ')', ')', '(', ')', ')', '(', ')', '(', '(')
# (')', '(', '(', ')', ')', '(', '(', ')', '(', ')')
# (')', ')', '(', '(', ')', ')', '(', '(', ')', '(')
# (')', '(', '(', '(', ')', ')', '(', '(', ')', ')')
# ('(', ')', ')', '(', ')', '(', '(', ')', ')', '(')
# (')', ')', '(', ')', ')', '(', '(', ')', '(', '(')
# ('(', ')', '(', ')', ')', '(', '(', ')', '(', ')')
# (')', ')', '(', ')', ')', '(', ')', '(', '(', '(')
# ('(', ')', ')', '(', '(', ')', '(', '(', ')', ')')
# (')', ')', '(', '(', ')', ')', '(', ')', '(', '(')
# (')', '(', '(', ')', ')', '(', ')', ')', '(', '(')
# (')', '(', '(', ')', ')', ')', '(', '(', ')', '(')
# ('(', ')', '(', '(', '(', ')', '(', ')', ')', ')')
# ('(', '(', ')', ')', ')', '(', ')', ')', '(', '(')
# ('(', '(', ')', '(', '(', ')', ')', ')', '(', ')')
# (')', ')', ')', ')', ')', '(', '(', '(', '(', '(')
# (')', ')', '(', '(', ')', '(', ')', '(', '(', ')')
# (')', '(', ')', ')', '(', '(', ')', '(', '(', ')')
# (')', '(', '(', ')', '(', ')', '(', '(', ')', ')')
# ('(', ')', '(', '(', '(', ')', ')', ')', '(', ')')
# (')', ')', ')', ')', '(', '(', '(', '(', ')', '(')
# ('(', '(', '(', ')', ')', ')', '(', ')', ')', '(')
# (')', '(', '(', ')', '(', ')', ')', '(', ')', '(')
# (')', '(', ')', ')', ')', ')', '(', '(', '(', '(')
# ('(', ')', '(', ')', ')', ')', '(', '(', '(', ')')
# ('(', '(', ')', '(', ')', ')', '(', ')', '(', ')')
# (')', ')', '(', ')', ')', '(', '(', '(', '(', ')')
# ('(', ')', ')', '(', ')', '(', '(', ')', '(', ')')
# (')', ')', ')', '(', '(', '(', '(', ')', ')', '(')
# ('(', ')', ')', ')', ')', '(', ')', '(', '(', '(')
# (')', ')', '(', ')', '(', ')', '(', ')', '(', '(')
# (')', '(', ')', '(', ')', '(', ')', '(', '(', ')')
# (')', '(', ')', '(', '(', ')', '(', '(', ')', ')')
# ('(', ')', '(', ')', '(', ')', ')', '(', '(', ')')
# []

# %%
import itertools

list(itertools.permutations(, 6))
# Out:
# 720

# %%
a = ['(', ')', '(', ')', ')', ')', ')', '(', '(', '(']
ans = ''
for el in a:
    ans += el
    
print(ans)
# Out:
# ()())))(((
